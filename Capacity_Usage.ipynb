# %% [markdown]
# #### Capacity usage: where the absolute usage is divided by the available protein, as indicated by the upper bounds of the usage_prot reactions,  the ratio of available enzyme that is used, calcuted by (absUsage/UB)

# %% [markdown]
# ####  Absolute usage: the specific enzyme usage in ug/gDCW/h, corresponding to the flux through the respective usage_prot reactions

# %% [markdown]
# ### Visualization of the GECKO Result - CapUsage of Phenylalanine tyrosine and tryptophan biosynthesis

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = [
    'sll0990', 'slr0090', 'slr0091', 'sll0828', 'sll0828', 'slr1867', 'slr0055', 'slr1979', 'slr0738',
    'sll1987', 'sll0109', 'sll1747', 'sll0934', 'slr2130', 'sll1112', 'slr0752', 'slr0546', 'sll1713',
    'sll1958', 'slr0036', 'sll0402', 'sll0480', 'sll1553', 'sll0454', 'slr2081', 'sll1662', 'slr0090',
    'sll0356', 'slr0444', 'slr1559', 'sll1669', 'slr0543', 'slr0966', 'slr1884', 'sll0480', 'sll1713',
    'sll1958', 'slr0036', 'sll0402', 'slr1031', 'ssr1720', 'ppd', 'nylA' , 'trpD' , 'trpE' , 'trpG' , 'katG' , 
    'aroH' , 'aroC' , 'ccmA' , 'aroB' , 'aroQ', 'eno', 'trpC', 'aspC', 'hisC', 'pheS' , 'pheT', 'tyrA', 'pheA', 'ppd', 'trpF', 'aroA',
    'aroE', 'aroK', 'trpA' , 'trpB', 'trpS', 'tyrS'
]

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(10, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for the Shikimate Pathway Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: slr0091
# Reactions: ['IMACTD', 'LCARS', 'NABTNO', 'GLYALDDr', 'ALDD2x', 'ALDD20x', 'BAMPPALDOX', 'GCALDD', 'ABUTD']
#
# Gene: trpD
# Reactions: ['ANPRT']
#
# Gene: sll0480
# Reactions: ['TYRTA', 'EHGLAT', 'PHETA1', 'ASPTA']
#
# Gene: aroC
# Reactions: ['CHORS']
#
# Gene: ccmA
# Reactions: ['DDPA']
#
# Gene: eno
# Reactions: ['DHQTi', 'ENO']
#
# Gene: trpC
# Reactions: ['IGPS']
#
# Gene: tyrA
# Reactions: ['PPND']
#
# Gene: aroA
# Reactions: ['PSCVT']
#
# Gene: aroE
# Reactions: ['SHK3Dr']
#
# Gene: aroK
# Reactions: ['SHKK']
#
# Gene: aspC
# Reactions: ['PHETA1', 'EHGLAT', 'ASPTA', 'SDPTA', 'CYSTA', 'TYRTA']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of Carbon fixation

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = [
    'sll0990', 'aspC', 'sll0480', 'gap2', 'prk', 'rbcL', 'rbcS', 'fbp', 'glpX'
]

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(10, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for Carbon fixation Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: sll0990
# Reactions: ['ALCD19', 'LALDO', '34DHOXPEGOX']
#
# Gene: aspC
# Reactions: ['PHETA1', 'EHGLAT', 'ASPTA', 'SDPTA', 'CYSTA', 'TYRTA']
#
# Gene: sll0480
# Reactions: ['TYRTA', 'EHGLAT', 'PHETA1', 'ASPTA']
#
# Gene: gap2
# Reactions: ['GAPDi_nadp']
#
# Gene: prk
# Reactions: ['PRUK']
#
# Gene: rbcL
# Reactions: ['RBPC', 'RBCh']
#
# Gene: rbcS
# Reactions: ['RBPC', 'RBCh']
#
# Gene: fbp
# Reactions: ['FBP', 'SBP']
#
# Gene: glpX
# Reactions: ['FBP', 'SBP']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of Glycolysis/Gluconeogenesis

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = [
    'glk', 'acs', 'slr0942', 'slr0091', 'yibO', 'eno', 'fda', 'cbbA', 'fbp', 'glpX', 
    'gap1', 'pdhB', 'odhB', 'phdD', 'pfkA', 'pgi', 'pgk', 'gpmB', 'ntcB', 'pgm', 'sll1758', 'tpi'
]

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(14, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for Glycolysis/Gluconeogenesis Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: glk
# Reactions: ['HEX1', 'GLUK_syn']
#
# Gene: acs
# Reactions: ['ACS']
#
# Gene: slr0942
# Reactions: ['ALCD2y']
#
# Gene: slr0091
# Reactions: ['IMACTD', 'LCARS', 'NABTNO', 'GLYALDDr', 'ALDD2x', 'ALDD20x', 'BAMPPALDOX', 'GCALDD', 'ABUTD']
#
# Gene: yibO
# Reactions: ['DPGM', 'PGM']
#
# Gene: eno
# Reactions: ['DHQTi', 'ENO']
#
# Gene: fda
# Reactions: ['FBA3', 'FBA']
#
# Gene: cbbA
# Reactions: ['FBA3', 'FBA', 'FBA2']
#
# Gene: fbp
# Reactions: ['FBP', 'SBP']
#
# Gene: glpX
# Reactions: ['FBP', 'SBP']
#
# Gene: gap1
# Reactions: ['GAPD']
#
# Gene: pdhB
# Reactions: ['PDH', 'PDHa']
#
# Gene: odhB
# Reactions: ['PDHbr', 'PDH']
#
# Gene: phdD
# Reactions: ['GLYCL', 'PDH', 'PDHcr']
#
# Gene: pfkA
# Reactions: ['PFK', 'PFK_3', 'PFK_2']
#
# Gene: pgi
# Reactions: ['PGI', 'G6PI3']
#
# Gene: pgk
# Reactions: ['PGK']
#
# Gene: gpmB
# Reactions: ['PGM']
#
# Gene: ntcB
# Reactions: ['PGM']
#
# Gene: pgm
# Reactions: ['PGAMT', 'PGMT']
#
# Gene: sll1758
# Reactions: ['PPM', 'PGMT', 'PGAMT']
#
# Gene: tpi
# Reactions: ['TPI']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of TCA Cycle

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = [
    'slr0665', 'gltA', 'fumC', 'icd', 'citH', 'sucC', 'sucD',  
]

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(10, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for TCA Cycle Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: slr0665
# Reactions: ['ACONT']
#
# Gene: gltA
# Reactions: ['CS']
#
# Gene: fumC
# Reactions: ['FUM']
#
# Gene: icd
# Reactions: ['ICDHyr']
#
# Gene: citH
# Reactions: ['MDH']
#
# Gene: sucC
# Reactions: ['SUCOAS']
#
# Gene: sucD
# Reactions: ['SUCOAS']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of Photosynthesis Genes

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = ['apca', 'apcb', 'apcc', 'ctaD', 'ctaE', 'cpcb', 'cpcB', 'cpcC', 'cpcD', 'cpcE', 
             'cpcF', 'cpcG', 'cydA', 'cydB', 'cytbd', 'fnor', 'frda', 'icfa', 'icfap', 'petA', 
             'petB', 'petC', 'petD', 'petF', 'petG', 'petH', 'petM', 'pete', 'petf', 'psaB', 
             'psaI', 'psaJ', 'psaK', 'psb13', 'psbB', 'psbF', 'psbJ', 'psbN', 'psbO', 'psbV', 
             'psbZ', 'psbm', 'sdhB', 'sdhB', 'slr1739', 'sll0550', 'sll1418', 'sll1521', 'ssr2016', 'ycf6', 'ycei']

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(18, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for Photosynthesis Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: ctaD
# Reactions: ['CYO1bpp_syn', 'CYO1b2_syn', 'CYO1b2pp_syn', 'CYO1b_syn']
#
# Gene: cydA
# Reactions: ['CYTBDpp_1', 'CYTBDu']
#
# Gene: petF
# Reactions: ['FNOR']
#
# Gene: petH
# Reactions: ['FNOR']
#
# Gene: ssr2016
# Reactions: ['FQR']
#
# Gene: sll1521
# Reactions: ['MEHLER']
#
# Gene: psb13
# Reactions: ['PSII']
#
# Gene: sll1418
# Reactions: ['PSII']
#
# Gene: slr1739
# Reactions: ['PSII']
#
# Gene: psaB
# Reactions: ['PSI', 'PSI_2']
#
# Gene: psaJ
# Reactions: ['PSI', 'PSI_2']
#
# Gene: psaK
# Reactions: ['PSI', 'PSI_2']
#
# Gene: psbB
# Reactions: ['PSII']
#
# Gene: psbO
# Reactions: ['PSII']
#
# Gene: psbV
# Reactions: ['PSII']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of Nitrogen metabolism Genes

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = ['sll0422', 'arcC', 'gltB', 'glnN', 'glnA', 'gdhA', 'slr2079', 'gltB and gltD', 'gcvT', 'narB', 'nirA', 'cynS']

# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(10, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for Nitrogen Metabolism Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: gcvT
# Reactions: ['GLYCL', 'GLYCL_2', 'FOMETRi']
#
# Gene: glnN
# Reactions: ['GLNS']
#
# Gene: narB
# Reactions: ['NAR_syn']
#
# Gene: nirA
# Reactions: ['NOR_syn']
#
# Gene: gdhA
# Reactions: ['GLUDy']

# %% [markdown]
# ### Visualization of the GECKO Result - Cap Usage of Transport Genes

# %%
import pandas as pd

# Read the CSV files into data frames
OP4_AllEnz = pd.read_csv('OP4_AllEnz.csv')
OP2_AllEnz = pd.read_csv('OP2_AllEnz.csv')
C_AllEnz = pd.read_csv('C_AllEnz.csv')

# Remove the single quotes from the Gene_ID column in each dataframe
OP4_AllEnz['Gene_ID'] = OP4_AllEnz['Gene_ID'].str.strip("'")
OP2_AllEnz['Gene_ID'] = OP2_AllEnz['Gene_ID'].str.strip("'")
C_AllEnz['Gene_ID'] = C_AllEnz['Gene_ID'].str.strip("'")

# List of unique Gene_IDs to compare
gene_list = ['sll0771', 'slr1145', 'sll1102', 'sll1103', 'sll1104', 'slr0040', 'slr0041', 'slr0043', 'slr0044', 'sll0834', 'slr1512', 'sll0026', 'sll0027', 'sll0223', 'sll0519', 'sll0520', 'sll0521', 'sll0522', 'sll1220', 'sll1221', 'sll1223', 'sll1262', 'sll8031', 'slr0261', 'slr1279', 'slr1280', 'slr1281', 'slr1302', 'slr1623', 'sll1732', 'sll1733', 'sll1734', 'sll1735', 'slr0467', 'slr0559', 'slr0949', 'slr1881', 'sll1270', 'slr1735', 'sll1450', 'sll1452', 'sll1453', 'sll0374', 'sll0764', 'slr0447', 'slr1200', 'slr1201', 'sll0108', 'sll0537', 'sll1017', 'sll0493', 'slr1508', 'slr1509', 'slr1452', 'slr1453', 'slr1454', 'slr1455', 'sll0679', 'sll0680', 'sll0681', 'sll0682', 'sll0683', 'sll0684', 'slr1247', 'slr1248', 'slr1249', 'slr1250', 'sll0738', 'sll0739', 'sll1878', 'slr0327', 'slr0513', 'slr1295', 'Sll1392', 'sll0273', 'sll0556', 'sll0689', 'slr0415', 'slr1595', 'slr1727', 'sll1598', 'sll1599', 'sll1600', 'slr0014', 'slr1216', 'slr2057', 'slr1950', 'sll1920', 'slr2043', 'slr2044', 'slr2045', 'sll0383', 'sll0384', 'sll0385', 'slr0798', 'slr0797', 'sll1614', 'slr1336', 'slr0529', 'slr0530', 'slr0531', 'slr0747']


# Filter the data frames for the unique Gene_IDs
OP4_filtered = OP4_AllEnz[OP4_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
OP2_filtered = OP2_AllEnz[OP2_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]
C_filtered = C_AllEnz[C_AllEnz['Gene_ID'].isin(gene_list)][['Gene_ID', 'CapUsage']]

# Merge the filtered data frames based on 'Gene_ID'
merged_df = pd.merge(C_filtered, OP2_filtered, on='Gene_ID', how='outer').drop_duplicates()
merged_df = pd.merge(merged_df, OP4_filtered, on='Gene_ID', how='outer').drop_duplicates()

# Rename the columns
merged_df.columns = ['Gene_ID', 'C_CapUsage', 'OP2_CapUsage', 'OP4_CapUsage']

# Print the merged and aggregated DataFrame
#print(merged_df)

# Plot the bar chart
ax = merged_df.plot(x='Gene_ID', kind='bar', figsize=(16, 6), rot=45, width=0.8, edgecolor='black')

# Set plot title and axis labels
plt.title('Comparison of CapUsage for Transport Genes', fontsize=16)
plt.xlabel('Gene ID', fontsize=12)
plt.ylabel('CapUsage', fontsize=12)

# Customize grid lines
plt.grid(axis='y', linestyle='--')

# Customize legend
plt.legend(fontsize=10)

# Adjust tick labels font size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Gene: slr1336
# Reactions: ['CA2t3pp']
#
# Gene: sll0384
# Reactions: ['NI2uabcpp', 'Cobalt2abcppI']
#
# Gene: sll0385
# Reactions: ['NI2uabcpp', 'Cobalt2abcppI']
#
# Gene: slr1508
# Reactions: ['DGDG181_9', 'MGDG184_6_9_12_15', 'DGDG182_9_12', 'MGDG181_9', 'MGDG183_6_9_12', 'Kt2pp', 'DGDG180', 'MGDG181', 'DGDG183_9_12_15', 'DGDG183_6_9_12', 'MGDG180', 'DGDG181', 'MGDG182_9_12', 'DGDG161', 'MGDG161', 'MGDG183_9_12_15', 'MGDG160', 'DGDG160', 'DGDG184_6_9_12_15']
#
# Gene: sll1220
# Reactions: ['NDH1_4pp', 'NDH1_1p', 'H2ASE_syn', 'NDH1_1u', 'NDH1_2p', 'NDH1_3u', 'NDH1_2u']
#
# Gene: slr1512
# Reactions: ['H2CO3_NAt_syn']
#
# Gene: sll0834
# Reactions: ['H2CO3_NAt_syn']
#
# Gene: sll0493
# Reactions: ['Kt2pp']
#
# Gene: slr1727
# Reactions: ['NAt3pp']
#
# Gene: sll0273
# Reactions: ['NAt3pp']
#
# Gene: sll0689
# Reactions: ['NAt3pp']
#
# Gene: sll0556
# Reactions: ['NAt3pp']
#
# Gene: sll1262
# Reactions: ['NDH1_4pp', 'NDH1_1p', 'NDH1_1u', 'NDH1_2p', 'NDH1_3u', 'NDH1_2u']
#
# Gene: slr1623
# Reactions: ['NDH1_4pp', 'NDH1_1p', 'NDH1_1u', 'NDH1_2p', 'NDH1_3u', 'NDH1_2u']
#
# Gene: sll1734
# Reactions: ['NDH1_3u']
#
# Gene: sll1735
# Reactions: ['NDH1_3u']
